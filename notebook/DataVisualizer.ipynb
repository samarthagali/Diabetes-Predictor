# %%
# !git clone -q https://github.com/Chandrahas-B/MLOps
# %cd MLOps
# Out:
# /content/MLOps

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("./diabetes-dataset.csv")
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            2      138             62             35        0  33.6
# 1            0       84             82             31      125  38.2
# 2            0      145              0              0        0  44.2
# 3            0      135             68             42      250  42.3
# 4            1      139             62             41      480  40.7
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.127   47        1
# 1                     0.233   23        0
# 2                     0.630   31        1
# 3                     0.365   24        1
# 4                     0.536   21        0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               2000 non-null   int64
#  1   Glucose                   2000 non-null   int64
#  2   BloodPressure             2000 non-null   int64
#  3   SkinThickness             2000 non-null   int64
#  4   Insulin                   2000 non-null   int64
#  5   BMI                       2000 non-null   float64
#  6   DiabetesPedigreeFunction  2000 non-null   float64
#  7   Age                       2000 non-null   int64
#  8   Outcome                   2000 non-null   int64
# dtypes: float64(2), int64(7)
# memory usage: 140.8 KB

# %%
age_groups = pd.cut(df['Age'], bins=range(0, 101, 10))
diabetes_counts = df.groupby([age_groups, 'Outcome']).size().unstack()
age_labels = [f'{interval.left}-{interval.right}' for interval in diabetes_counts.index]
plt.figure(figsize=(10, 6))
bars = plt.bar(range(len(age_labels)), diabetes_counts[1], color='blue')
for bar in bars:
    if bar.get_height() > 100:
        bar.set_color('red')
plt.title('Diabetes vs Age')
plt.xlabel('Age Group')
plt.ylabel('Count')
plt.xticks(range(len(age_labels)), age_labels, rotation=0)
legend_labels = ['Low  Count Diabetes', 'High Count Diabetes']
legend_patches = [plt.Rectangle((0, 0), 1, 1, color='blue'),
                  plt.Rectangle((0, 0), 1, 1, color='red')]
plt.legend(legend_patches, legend_labels)

plt.tight_layout()
plt.show()

# %%
bp_groups = pd.cut(df['BloodPressure'], bins=range(0, 101, 10))
diabetes_counts = df.groupby([bp_groups, 'Outcome']).size().unstack()
bp_labels = [f'{interval.left}-{interval.right}' for interval in diabetes_counts.index]
plt.figure(figsize=(10, 6))
bars = plt.bar(range(len(bp_labels)),diabetes_counts[1], color='blue')
for bar in bars:
    if bar.get_height() > 100:
        bar.set_color('red')
plt.title('Diabetes vs Blood pressure')
plt.xlabel('BP Group')
plt.ylabel('Count')
plt.xticks(range(len(bp_labels)), bp_labels, rotation=0)
legend_labels = ['Low  Count Diabetes', 'High Count Diabetes']
legend_patches = [plt.Rectangle((0, 0), 1, 1, color='blue'),
                  plt.Rectangle((0, 0), 1, 1, color='red')]
plt.legend(legend_patches, legend_labels)
plt.tight_layout()
plt.show()

# %%
age_min = df['BMI'].min()
age_max = df['BMI'].max()
print(age_min,age_max)
# Out:
# 0.0 80.6

# %%
groups = pd.cut(df['Insulin'], bins=range(0, 751, 75))
diabetes_counts = df.groupby([groups, 'Outcome']).size().unstack()
labels = [f'{interval.left}-{interval.right}' for interval in diabetes_counts.index]
plt.figure(figsize=(10, 6))
bars = plt.bar(range(len(bp_labels)),diabetes_counts[1], color='blue')
for bar in bars:
    if bar.get_height() > 80:
        bar.set_color('red')
plt.title('Diabetes vs Insulin')
plt.xlabel('Insulin Count')
plt.ylabel('Count')
plt.xticks(range(len(labels)), labels, rotation=0)
legend_labels = ['Low  Count Diabetes', 'High Count Diabetes']
legend_patches = [plt.Rectangle((0, 0), 1, 1, color='blue'),
                  plt.Rectangle((0, 0), 1, 1, color='red')]
plt.legend(legend_patches, legend_labels)
plt.tight_layout()
plt.show()

# %%
groups = pd.cut(df['SkinThickness'], bins=range(0, 111, 11))
diabetes_counts = df.groupby([groups, 'Outcome']).size().unstack()
labels = [f'{interval.left}-{interval.right}' for interval in diabetes_counts.index]
plt.figure(figsize=(10, 6))
bars = plt.bar(range(len(bp_labels)),diabetes_counts[1], color='blue')
for bar in bars:
    if bar.get_height() > 100:
        bar.set_color('red')
plt.title('Diabetes vs SkinThickness')
plt.xlabel('SkinThickness')
plt.ylabel('Count')
plt.xticks(range(len(labels)), labels, rotation=0)
legend_labels = ['Low  Count Diabetes', 'High Count Diabetes']
legend_patches = [plt.Rectangle((0, 0), 1, 1, color='blue'),
                  plt.Rectangle((0, 0), 1, 1, color='red')]
plt.legend(legend_patches, legend_labels)
plt.tight_layout()
plt.show()

# %%
groups = pd.cut(df['BMI'], bins=range(0, 81, 8))
diabetes_counts = df.groupby([groups, 'Outcome']).size().unstack()
labels = [f'{interval.left}-{interval.right}' for interval in diabetes_counts.index]
plt.figure(figsize=(10, 6))
bars = plt.bar(range(len(bp_labels)),diabetes_counts[1], color='blue')
for bar in bars:
    if bar.get_height() > 100:
        bar.set_color('red')
plt.title('Diabetes vs BMI')
plt.xlabel('BMI')
plt.ylabel('Count')
plt.xticks(range(len(labels)), labels, rotation=0)
legend_labels = ['Low  Count Diabetes', 'High Count Diabetes']
legend_patches = [plt.Rectangle((0, 0), 1, 1, color='blue'),
                  plt.Rectangle((0, 0), 1, 1, color='red')]
plt.legend(legend_patches, legend_labels)
plt.tight_layout()
plt.show()
